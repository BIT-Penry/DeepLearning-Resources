# %% [markdown]
# # 1 准备阶段

# %% [markdown]
# ## 1.1 导入必要包

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

import torchvision

import os
import time

from PIL import Image

# %% [markdown]
# ## 1.2 准备数据集

# %%
train_data = torchvision.datasets.CIFAR10(
    root="../data/CIFAR10/", 
    train=True, 
    transform=torchvision.transforms.ToTensor(),
    download=True
)

test_data = torchvision.datasets.CIFAR10(
    root="../data/CIFAR10/", 
    train=False, 
    transform=torchvision.transforms.ToTensor(),
    download=True
)

# %% [markdown]
# ## 1.3 数据集预览和预处理

# %%
train_data_size = len(train_data)
test_data_size = len(test_data)
print("训练集的数据长度为：{}".format(train_data_size))
print("测试集的数据长度为：{}".format(test_data_size))
# Out:
# 训练集的数据长度为：50000
# 测试集的数据长度为：10000

# %% [markdown]
# 利用`DataLoader`加载数据

# %%
train_dataloader = DataLoader(dataset=train_data, batch_size=64)
test_dataloader = DataLoader(dataset=test_data, batch_size=64)

# %% [markdown]
# # 2 搭建神经网络
#
# <p align="center">
#   <img src="https://penry-1352739541.cos.ap-beijing.myqcloud.com/img/20251224124947699.png" alt="" width="55%" height="height">
# </p>

# %%
class Model_CIFAR(nn.Module):
    def __init__(self):
        super(Model_CIFAR, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=5, stride=1, padding=2),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(in_channels=32, out_channels=32, kernel_size=5, stride=1, padding=2),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, stride=1, padding=2),
            nn.MaxPool2d(kernel_size=2),
            nn.Flatten()
        )

        self.classfier = nn.Sequential(
            nn.Linear(in_features=64*4*4, out_features=64),
            nn.Linear(in_features=64, out_features=10)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classfier(x)
        return x

# %% [markdown]
# # 3 创建模型及后续步骤
#
# 只有以下类型可以用cuda加速，也就是放到GPU上：
# - 网络模型
# - 损失函数
# - 数据

# %% [markdown]
# 第一种：使用以下操作转移到GPU上操作
# - `model.cuda()`
# - `loss_fn.cuda()`
# - `imgs.cuda()`
# - `targets.cuda()`

# %%
# 创建网络模型
model = Model_CIFAR()
model = model.cuda()

# 创建损失函数
loss_fn = nn.CrossEntropyLoss()
loss_fn = loss_fn.cuda()

# 定义优化器
learning_rate = 1e-2
optimizer = torch.optim.SGD(params=model.parameters(), lr=learning_rate)

# 设置训练网络参数
epoch = 20 # 训练轮次
total_train_step = 0 # 记录训练次数
total_test_step = 0 # 记录测试次数
best_accuracy = 0.0 # 记录最佳准确率

# 添加tensorboard
writer = SummaryWriter('../logs/logs_train')

start_time = time.time()
for i in range(epoch):
    print(f"-------第{i+1}轮训练开始-------")

    # 训练开始
    model.train()
    total_train_loss = 0.0
    avg_train_loss = 0.0
    for data in train_dataloader:
        imgs, targets = data
        imgs = imgs.cuda()
        targets = targets.cuda()
        output = model(imgs)
        loss = loss_fn(output, targets)
        # 优化器优化模型
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_train_step += 1
        total_train_loss += loss.item()

        # 每100个batch打印一次
        if total_train_step % 100 == 0:
            end_time = time.time()
            print(f"训练100个batch耗时：{end_time - start_time}秒")
            print(f"训练次数：{total_train_step}， Loss：{loss.item()}")
            writer.add_scalar(tag='train_loss', scalar_value=loss.item(), global_step=total_train_step)

    # 打印每个epoch的平均loss
    avg_train_loss = total_train_loss / len(train_dataloader)
    print(f"第 {i+1} 轮训练，平均 Loss：{avg_train_loss:.4f}")

    # 测试阶段
    model.eval()
    total_test_loss= 0.0
    total_accuracy = 0.0
    avg_test_loss = 0.0

    with torch.no_grad(): # 测试时候不需要计算梯度
        for data in test_dataloader:
            imgs, targets = data
            imgs = imgs.cuda()
            targets = targets.cuda()
            outputs = model(imgs)
            loss = loss_fn(outputs, targets)

            total_test_loss += loss.item()

            # 计算准确率
            accuracy = (outputs.argmax(1) == targets).sum()
            total_accuracy += accuracy

    avg_test_loss = total_test_loss / len(test_dataloader)
    overall_accuracy = total_accuracy / test_data_size
    print(f"第 {i+1} 轮测试，平均 Loss：{avg_test_loss:.4f}，准确率：{overall_accuracy:.2%}")

    writer.add_scalar(tag='test_loss', scalar_value=avg_test_loss, global_step=total_test_step)

    total_test_step += 1

    # 模型保存：每5个epoch保存一次模型
    if (i+1)%5 == 0:
        torch.save(model.state_dict(), f"../checkpoints/CIFRA10/model_epoch_{i+1}.pth")
        print(f"保存第{i+1}轮次的模型")

    # 最佳模型保存
    if overall_accuracy > best_accuracy:
        best_accuracy = overall_accuracy
        torch.save(model.state_dict(), "../checkpoints/CIFRA10/best_model.pth")
        print(f"保存最佳模型！准确率：{best_accuracy:.2%}")

    print()

writer.close()

print(f"🎉 训练完成！最佳准确率：{best_accuracy:.2%}")
print(f"模型已保存到 ../checkpoints/ 目录")
# Out:
# -------第1轮训练开始-------
# 训练100个batch耗时：0.34072208404541016秒
# 训练次数：100， Loss：2.286067485809326
# 训练100个batch耗时：0.6848113536834717秒
# 训练次数：200， Loss：2.294322967529297
# 训练100个batch耗时：1.0136561393737793秒
# 训练次数：300， Loss：2.259579658508301
# 训练100个batch耗时：1.3355181217193604秒
# 训练次数：400， Loss：2.1823830604553223
# 训练100个batch耗时：1.6576180458068848秒
# 训练次数：500， Loss：2.147213935852051
# 训练100个batch耗时：1.980560064315796秒
# 训练次数：600， Loss：2.116014242172241
# 训练100个batch耗时：2.2948033809661865秒
# 训练次数：700， Loss：1.9936423301696777
# 第 1 轮训练，平均 Loss：2.1812
# 第 1 轮测试，平均 Loss：1.9707，准确率：28.04%
# 保存最佳模型！准确率：28.04%
#
# -------第2轮训练开始-------
# 训练100个batch耗时：2.995689630508423秒
# 训练次数：800， Loss：1.83610999584198
# 训练100个batch耗时：3.3105227947235107秒
# 训练次数：900， Loss：1.7453320026397705
# 训练100个batch耗时：3.6254866123199463秒
# 训练次数：1000， Loss：1.907186508178711
# 训练100个batch耗时：3.9419126510620117秒
# 训练次数：1100， Loss：2.043125629425049
# 训练100个batch耗时：4.2561328411102295秒
# 训练次数：1200， Loss：1.6853785514831543
# 训练100个batch耗时：4.593693017959595秒
# 训练次数：1300， Loss：1.5909383296966553
# 训练100个batch耗时：4.93189001083374秒
# 训练次数：1400， Loss：1.706910490989685
# 训练100个batch耗时：5.245325326919556秒
# 训练次数：1500， Loss：1.749018669128418
# 第 2 轮训练，平均 Loss：1.8089
# 第 2 轮测试，平均 Loss：1.8363，准确率：34.18%
# 保存最佳模型！准确率：34.18%
#
# -------第3轮训练开始-------
# 训练100个batch耗时：5.9845147132873535秒
# 训练次数：1600， Loss：1.662322759628296
# 训练100个batch耗时：6.30075740814209秒
# 训练次数：1700， Loss：1.6420416831970215
# 训练100个batch耗时：6.6465559005737305秒
# 训练次数：1800， Loss：1.9485678672790527
# 训练100个batch耗时：6.981075763702393秒
# 训练次数：1900， Loss：1.7218337059020996
# 训练100个batch耗时：7.295414924621582秒
# 训练次数：2000， Loss：1.923550009727478
# 训练100个batch耗时：7.611795663833618秒
# 训练次数：2100， Loss：1.528135061264038
# 训练100个batch耗时：7.927854537963867秒
# 训练次数：2200， Loss：1.4618278741836548
# 训练100个batch耗时：8.246619701385498秒
# 训练次数：2300， Loss：1.7922329902648926
# 第 3 轮训练，平均 Loss：1.6428
# 第 3 轮测试，平均 Loss：1.6848，准确率：38.96%
# 保存最佳模型！准确率：38.96%
#
# -------第4轮训练开始-------
# 训练100个batch耗时：8.947704792022705秒
# 训练次数：2400， Loss：1.718559741973877
# 训练100个batch耗时：9.258625030517578秒
# 训练次数：2500， Loss：1.3577475547790527
# 训练100个batch耗时：9.575637340545654秒
# 训练次数：2600， Loss：1.5887459516525269
# 训练100个batch耗时：9.891782999038696秒
# 训练次数：2700， Loss：1.6875009536743164
# 训练100个batch耗时：10.209012269973755秒
# 训练次数：2800， Loss：1.5200023651123047
# 训练100个batch耗时：10.525162935256958秒
# 训练次数：2900， Loss：1.6178631782531738
# 训练100个batch耗时：10.837360382080078秒
# 训练次数：3000， Loss：1.3577632904052734
# 训练100个batch耗时：11.153877973556519秒
# 训练次数：3100， Loss：1.5108834505081177
# 第 4 轮训练，平均 Loss：1.5513
# 第 4 轮测试，平均 Loss：1.6759，准确率：39.55%
# 保存最佳模型！准确率：39.55%
#
# -------第5轮训练开始-------
# 训练100个batch耗时：11.851871728897095秒
# 训练次数：3200， Loss：1.3714244365692139
# 训练100个batch耗时：12.165117025375366秒
# 训练次数：3300， Loss：1.5238981246948242
# 训练100个batch耗时：12.476269483566284秒
# 训练次数：3400， Loss：1.4798089265823364
# 训练100个batch耗时：12.790534496307373秒
# 训练次数：3500， Loss：1.5815207958221436
# 训练100个batch耗时：13.10377025604248秒
# 训练次数：3600， Loss：1.587774395942688
# 训练100个batch耗时：13.41971206665039秒
# 训练次数：3700， Loss：1.3769292831420898
# 训练100个batch耗时：13.732378244400024秒
# 训练次数：3800， Loss：1.2727042436599731
# 训练100个batch耗时：14.051142930984497秒
# 训练次数：3900， Loss：1.4437577724456787
# 第 5 轮训练，平均 Loss：1.4734
# 第 5 轮测试，平均 Loss：1.6342，准确率：41.36%
# 保存第5轮次的模型
# 保存最佳模型！准确率：41.36%
#
# -------第6轮训练开始-------
# 训练100个batch耗时：14.757993936538696秒
# 训练次数：4000， Loss：1.4241979122161865
# 训练100个batch耗时：15.071150302886963秒
# 训练次数：4100， Loss：1.4409887790679932
# 训练100个batch耗时：15.388948440551758秒
# 训练次数：4200， Loss：1.5256667137145996
# 训练100个batch耗时：15.705310821533203秒
# 训练次数：4300， Loss：1.198911190032959
# 训练100个batch耗时：16.021587133407593秒
# 训练次数：4400， Loss：1.1384506225585938
# 训练100个batch耗时：16.336163759231567秒
# 训练次数：4500， Loss：1.4188766479492188
# 训练100个batch耗时：16.649386644363403秒
# 训练次数：4600， Loss：1.4301724433898926
# 第 6 轮训练，平均 Loss：1.4003
# 第 6 轮测试，平均 Loss：1.5577，准确率：44.01%
# 保存最佳模型！准确率：44.01%
#
# -------第7轮训练开始-------
# 训练100个batch耗时：17.34277653694153秒
# 训练次数：4700， Loss：1.2946197986602783
# 训练100个batch耗时：17.649719953536987秒
# 训练次数：4800， Loss：1.558927297592163
# 训练100个batch耗时：17.963690042495728秒
# 训练次数：4900， Loss：1.3380968570709229
# 训练100个batch耗时：18.275620222091675秒
# 训练次数：5000， Loss：1.4335558414459229
# 训练100个batch耗时：18.600048780441284秒
# 训练次数：5100， Loss：0.9986114501953125
# 训练100个batch耗时：18.915436506271362秒
# 训练次数：5200， Loss：1.2744789123535156
# 训练100个batch耗时：19.23338484764099秒
# 训练次数：5300， Loss：1.2423903942108154
# 训练100个batch耗时：19.54965329170227秒
# 训练次数：5400， Loss：1.353464126586914
# 第 7 轮训练，平均 Loss：1.3312
# 第 7 轮测试，平均 Loss：1.4584，准确率：47.55%
# 保存最佳模型！准确率：47.55%
#
# -------第8轮训练开始-------
# 训练100个batch耗时：20.249131441116333秒
# 训练次数：5500， Loss：1.2193918228149414
# 训练100个batch耗时：20.558833122253418秒
# 训练次数：5600， Loss：1.1871216297149658
# 训练100个batch耗时：20.87378215789795秒
# 训练次数：5700， Loss：1.2028595209121704
# 训练100个batch耗时：21.18890690803528秒
# 训练次数：5800， Loss：1.2063422203063965
# 训练100个batch耗时：21.503267288208008秒
# 训练次数：5900， Loss：1.3875765800476074
# 训练100个batch耗时：21.820957899093628秒
# 训练次数：6000， Loss：1.574336290359497
# 训练100个batch耗时：22.13454008102417秒
# 训练次数：6100， Loss：1.055680751800537
# 训练100个batch耗时：22.45227813720703秒
# 训练次数：6200， Loss：1.0934696197509766
# 第 8 轮训练，平均 Loss：1.2666
# 第 8 轮测试，平均 Loss：1.3643，准确率：51.22%
# 保存最佳模型！准确率：51.22%
#
# -------第9轮训练开始-------
# 训练100个batch耗时：23.146332263946533秒
# 训练次数：6300， Loss：1.4215316772460938
# 训练100个batch耗时：23.457823753356934秒
# 训练次数：6400， Loss：1.2019307613372803
# 训练100个batch耗时：23.770972967147827秒
# 训练次数：6500， Loss：1.5654960870742798
# 训练100个batch耗时：24.086262702941895秒
# 训练次数：6600， Loss：1.0577788352966309
# 训练100个batch耗时：24.403505325317383秒
# 训练次数：6700， Loss：1.0702197551727295
# 训练100个batch耗时：24.719212532043457秒
# 训练次数：6800， Loss：1.1870990991592407
# 训练100个batch耗时：25.03694796562195秒
# 训练次数：6900， Loss：1.132232904434204
# 训练100个batch耗时：25.35109853744507秒
# 训练次数：7000， Loss：0.8912606239318848
# 第 9 轮训练，平均 Loss：1.2080
# 第 9 轮测试，平均 Loss：1.2953，准确率：54.08%
# 保存最佳模型！准确率：54.08%
#
# -------第10轮训练开始-------
# 训练100个batch耗时：26.054239988327026秒
# 训练次数：7100， Loss：1.3211003541946411
# 训练100个batch耗时：26.36700677871704秒
# 训练次数：7200， Loss：0.9838049411773682
# 训练100个batch耗时：26.6834933757782秒
# 训练次数：7300， Loss：1.149413824081421
# 训练100个batch耗时：26.998429775238037秒
# 训练次数：7400， Loss：0.8380576372146606
# 训练100个batch耗时：27.315380334854126秒
# 训练次数：7500， Loss：1.3026450872421265
# 训练100个batch耗时：27.629698276519775秒
# 训练次数：7600， Loss：1.2045539617538452
# 训练100个batch耗时：27.943936586380005秒
# 训练次数：7700， Loss：0.9109113216400146
# 训练100个batch耗时：28.262413501739502秒
# 训练次数：7800， Loss：1.268034815788269
# 第 10 轮训练，平均 Loss：1.1556
# 第 10 轮测试，平均 Loss：1.2434，准确率：55.91%
# 保存第10轮次的模型
# 保存最佳模型！准确率：55.91%
#
# -------第11轮训练开始-------
# 训练100个batch耗时：28.963682413101196秒
# 训练次数：7900， Loss：1.3864202499389648
# 训练100个batch耗时：29.281083822250366秒
# 训练次数：8000， Loss：1.1006066799163818
# 训练100个batch耗时：29.598912954330444秒
# 训练次数：8100， Loss：0.965004026889801
# 训练100个batch耗时：29.916113138198853秒
# 训练次数：8200， Loss：1.266861081123352
# 训练100个batch耗时：30.2337703704834秒
# 训练次数：8300， Loss：1.2402151823043823
# 训练100个batch耗时：30.55638289451599秒
# 训练次数：8400， Loss：1.033612847328186
# 训练100个batch耗时：30.87652015686035秒
# 训练次数：8500， Loss：1.1474456787109375
# 训练100个batch耗时：31.190284729003906秒
# 训练次数：8600， Loss：0.8843429088592529
# 第 11 轮训练，平均 Loss：1.1087
# 第 11 轮测试，平均 Loss：1.2011，准确率：57.43%
# 保存最佳模型！准确率：57.43%
#
# -------第12轮训练开始-------
# 训练100个batch耗时：31.894076108932495秒
# 训练次数：8700， Loss：1.2088403701782227
# 训练100个batch耗时：32.21237230300903秒
# 训练次数：8800， Loss：1.3830678462982178
# 训练100个batch耗时：32.53207325935364秒
# 训练次数：8900， Loss：1.0120536088943481
# 训练100个batch耗时：32.84509992599487秒
# 训练次数：9000， Loss：1.1022342443466187
# 训练100个batch耗时：33.160693645477295秒
# 训练次数：9100， Loss：1.1011223793029785
# 训练100个batch耗时：33.47988224029541秒
# 训练次数：9200， Loss：1.0385290384292603
# 训练100个batch耗时：33.798142194747925秒
# 训练次数：9300， Loss：1.116650938987732
# 第 12 轮训练，平均 Loss：1.0669
# 第 12 轮测试，平均 Loss：1.1674，准确率：59.04%
# 保存最佳模型！准确率：59.04%
#
# -------第13轮训练开始-------
# 训练100个batch耗时：34.495150327682495秒
# 训练次数：9400， Loss：0.8494051694869995
# 训练100个batch耗时：34.80732250213623秒
# 训练次数：9500， Loss：1.2760848999023438
# 训练100个batch耗时：35.11965584754944秒
# 训练次数：9600， Loss：0.9969642758369446
# 训练100个batch耗时：35.432374000549316秒
# 训练次数：9700， Loss：1.1358680725097656
# 训练100个batch耗时：35.74849271774292秒
# 训练次数：9800， Loss：0.9425334930419922
# 训练100个batch耗时：36.06223702430725秒
# 训练次数：9900， Loss：0.9493978023529053
# 训练100个batch耗时：36.374847650527954秒
# 训练次数：10000， Loss：0.9265601634979248
# 训练100个batch耗时：36.68902039527893秒
# 训练次数：10100， Loss：0.976711630821228
# 第 13 轮训练，平均 Loss：1.0290
# 第 13 轮测试，平均 Loss：1.1311，准确率：60.68%
# 保存最佳模型！准确率：60.68%
#
# -------第14轮训练开始-------
# 训练100个batch耗时：37.38453793525696秒
# 训练次数：10200， Loss：0.8673319220542908
# 训练100个batch耗时：37.69978928565979秒
# 训练次数：10300， Loss：0.9689894914627075
# 训练100个batch耗时：38.015955209732056秒
# 训练次数：10400， Loss：1.162426471710205
# 训练100个batch耗时：38.3245313167572秒
# 训练次数：10500， Loss：0.8352883458137512
# 训练100个batch耗时：38.636733293533325秒
# 训练次数：10600， Loss：0.9149835705757141
# 训练100个batch耗时：38.949866771698秒
# 训练次数：10700， Loss：0.698555588722229
# 训练100个batch耗时：39.26377725601196秒
# 训练次数：10800， Loss：0.9000458717346191
# 训练100个batch耗时：39.57272672653198秒
# 训练次数：10900， Loss：0.9808405637741089
# 第 14 轮训练，平均 Loss：0.9946
# 第 14 轮测试，平均 Loss：1.1011，准确率：61.81%
# 保存最佳模型！准确率：61.81%
#
# -------第15轮训练开始-------
# 训练100个batch耗时：40.26934027671814秒
# 训练次数：11000， Loss：1.124884843826294
# 训练100个batch耗时：40.582526445388794秒
# 训练次数：11100， Loss：0.9221031069755554
# 训练100个batch耗时：40.89778757095337秒
# 训练次数：11200， Loss：1.0049028396606445
# 训练100个batch耗时：41.20913243293762秒
# 训练次数：11300， Loss：1.174432635307312
# 训练100个batch耗时：41.52593421936035秒
# 训练次数：11400， Loss：0.7772478461265564
# 训练100个batch耗时：41.847177267074585秒
# 训练次数：11500， Loss：1.043863296508789
# 训练100个batch耗时：42.16478681564331秒
# 训练次数：11600， Loss：0.910189151763916
# 训练100个batch耗时：42.47905373573303秒
# 训练次数：11700， Loss：0.9361834526062012
# 第 15 轮训练，平均 Loss：0.9630
# 第 15 轮测试，平均 Loss：1.0826，准确率：62.67%
# 保存第15轮次的模型
# 保存最佳模型！准确率：62.67%
#
# -------第16轮训练开始-------
# 训练100个batch耗时：43.182661056518555秒
# 训练次数：11800， Loss：0.8853001594543457
# 训练100个batch耗时：43.49828028678894秒
# 训练次数：11900， Loss：0.9764049053192139
# 训练100个batch耗时：43.82112383842468秒
# 训练次数：12000， Loss：0.8327945470809937
# 训练100个batch耗时：44.14179825782776秒
# 训练次数：12100， Loss：0.9438446164131165
# 训练100个batch耗时：44.46074414253235秒
# 训练次数：12200， Loss：0.9928380846977234
# 训练100个batch耗时：44.77899622917175秒
# 训练次数：12300， Loss：0.8912890553474426
# 训练100个batch耗时：45.099329471588135秒
# 训练次数：12400， Loss：0.8168201446533203
# 训练100个batch耗时：45.41252779960632秒
# 训练次数：12500， Loss：0.7578652501106262
# 第 16 轮训练，平均 Loss：0.9336
# 第 16 轮测试，平均 Loss：1.0702，准确率：63.19%
# 保存最佳模型！准确率：63.19%
#
# -------第17轮训练开始-------
# 训练100个batch耗时：46.11530828475952秒
# 训练次数：12600， Loss：0.8666625022888184
# 训练100个batch耗时：46.43054223060608秒
# 训练次数：12700， Loss：0.9604771733283997
# 训练100个batch耗时：46.74803042411804秒
# 训练次数：12800， Loss：0.7692662477493286
# 训练100个batch耗时：47.06380558013916秒
# 训练次数：12900， Loss：1.1143728494644165
# 训练100个batch耗时：47.386539936065674秒
# 训练次数：13000， Loss：1.018110752105713
# 训练100个batch耗时：47.70200061798096秒
# 训练次数：13100， Loss：0.6428045630455017
# 训练100个batch耗时：48.01562786102295秒
# 训练次数：13200， Loss：0.8021190166473389
# 第 17 轮训练，平均 Loss：0.9060
# 第 17 轮测试，平均 Loss：1.0613，准确率：63.61%
# 保存最佳模型！准确率：63.61%
#
# -------第18轮训练开始-------
# 训练100个batch耗时：48.716577768325806秒
# 训练次数：13300， Loss：1.0346083641052246
# 训练100个batch耗时：49.035314321517944秒
# 训练次数：13400， Loss：0.8076673746109009
# 训练100个batch耗时：49.3489408493042秒
# 训练次数：13500， Loss：0.8523412942886353
# 训练100个batch耗时：49.661582469940186秒
# 训练次数：13600， Loss：1.281860113143921
# 训练100个batch耗时：49.9764506816864秒
# 训练次数：13700， Loss：0.843386173248291
# 训练100个batch耗时：50.29286980628967秒
# 训练次数：13800， Loss：0.9897979497909546
# 训练100个batch耗时：50.60567378997803秒
# 训练次数：13900， Loss：0.7249519228935242
# 训练100个batch耗时：50.922521352767944秒
# 训练次数：14000， Loss：0.757081925868988
# 第 18 轮训练，平均 Loss：0.8800
# 第 18 轮测试，平均 Loss：1.0515，准确率：64.29%
# 保存最佳模型！准确率：64.29%
#
# -------第19轮训练开始-------
# 训练100个batch耗时：51.6340217590332秒
# 训练次数：14100， Loss：1.04343843460083
# 训练100个batch耗时：51.94989204406738秒
# 训练次数：14200， Loss：0.8782658576965332
# 训练100个batch耗时：52.26474714279175秒
# 训练次数：14300， Loss：0.9968668222427368
# 训练100个batch耗时：52.58035635948181秒
# 训练次数：14400， Loss：0.9043710827827454
# 训练100个batch耗时：52.896076917648315秒
# 训练次数：14500， Loss：0.9463963508605957
# 训练100个batch耗时：53.2155327796936秒
# 训练次数：14600， Loss：1.0590242147445679
# 训练100个batch耗时：53.53392767906189秒
# 训练次数：14700， Loss：0.7355158925056458
# 训练100个batch耗时：53.852628231048584秒
# 训练次数：14800， Loss：1.1662403345108032
# 第 19 轮训练，平均 Loss：0.8550
# 第 19 轮测试，平均 Loss：1.0521，准确率：64.52%
# 保存最佳模型！准确率：64.52%
#
# -------第20轮训练开始-------
# 训练100个batch耗时：54.5591299533844秒
# 训练次数：14900， Loss：0.6224038004875183
# 训练100个batch耗时：54.87410497665405秒
# 训练次数：15000， Loss：0.8537459969520569
# 训练100个batch耗时：55.1884126663208秒
# 训练次数：15100， Loss：0.725336492061615
# 训练100个batch耗时：55.50308847427368秒
# 训练次数：15200， Loss：0.8764462471008301
# 训练100个batch耗时：55.817864179611206秒
# 训练次数：15300， Loss：0.6503069400787354
# 训练100个batch耗时：56.13539910316467秒
# 训练次数：15400， Loss：0.8108537793159485
# 训练100个batch耗时：56.4516487121582秒
# 训练次数：15500， Loss：1.0292820930480957
# 训练100个batch耗时：56.76632595062256秒
# 训练次数：15600， Loss：0.8627078533172607
# 第 20 轮训练，平均 Loss：0.8312
# 第 20 轮测试，平均 Loss：1.0561，准确率：64.40%
# 保存第20轮次的模型
#
# 🎉 训练完成！最佳准确率：64.52%
# 模型已保存到 ../checkpoints/ 目录

# %% [markdown]
# 第二种：使用定义设备
# - `device = torch.device("cpu")`
# - `device = torch.device("cuda")`
# - `model = model.to(device)`
# - `loss_fn = loss_fn.to(device)`
# - `imgs = imgs.to(device)`
# - `targets = targets.to(device)`

# %%
# 定义训练的设备
device = torch.device("cpu")

# 创建网络模型
model = Model_CIFAR()
model.to(device)

# 创建损失函数
loss_fn = nn.CrossEntropyLoss()
loss_fn.to(device)

# 定义优化器
learning_rate = 1e-2
optimizer = torch.optim.SGD(params=model.parameters(), lr=learning_rate)

# 设置训练网络参数
epoch = 20 # 训练轮次
total_train_step = 0 # 记录训练次数
total_test_step = 0 # 记录测试次数
best_accuracy = 0.0 # 记录最佳准确率

# 添加tensorboard
writer = SummaryWriter('../logs/logs_train')

start_time = time.time()
for i in range(epoch):
    print(f"-------第{i+1}轮训练开始-------")

    # 训练开始
    model.train()
    total_train_loss = 0.0
    avg_train_loss = 0.0
    for data in train_dataloader:
        imgs, targets = data
        imgs = imgs.to(device)
        targets = targets.to(device)
        output = model(imgs)
        loss = loss_fn(output, targets)
        # 优化器优化模型
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_train_step += 1
        total_train_loss += loss.item()

        # 每100个batch打印一次
        if total_train_step % 100 == 0:
            end_time = time.time()
            print(f"训练100个batch耗时：{end_time - start_time}秒")
            print(f"训练次数：{total_train_step}， Loss：{loss.item()}")
            writer.add_scalar(tag='train_loss', scalar_value=loss.item(), global_step=total_train_step)

    # 打印每个epoch的平均loss
    avg_train_loss = total_train_loss / len(train_dataloader)
    print(f"第 {i+1} 轮训练，平均 Loss：{avg_train_loss:.4f}")

    # 测试阶段
    model.eval()
    total_test_loss= 0.0
    total_accuracy = 0.0
    avg_test_loss = 0.0

    with torch.no_grad(): # 测试时候不需要计算梯度
        for data in test_dataloader:
            imgs, targets = data
            imgs = imgs.to(device)
            targets = targets.to(device)
            outputs = model(imgs)
            loss = loss_fn(outputs, targets)

            total_test_loss += loss.item()

            # 计算准确率
            accuracy = (outputs.argmax(1) == targets).sum()
            total_accuracy += accuracy

    avg_test_loss = total_test_loss / len(test_dataloader)
    overall_accuracy = total_accuracy / test_data_size
    print(f"第 {i+1} 轮测试，平均 Loss：{avg_test_loss:.4f}，准确率：{overall_accuracy:.2%}")

    writer.add_scalar(tag='test_loss', scalar_value=avg_test_loss, global_step=total_test_step)

    total_test_step += 1

    # 模型保存：每5个epoch保存一次模型
    if (i+1)%5 == 0:
        torch.save(model.state_dict(), f"../checkpoints/CIFRA10/model_epoch_{i+1}.pth")
        print(f"保存第{i+1}轮次的模型")

    # 最佳模型保存
    if overall_accuracy > best_accuracy:
        best_accuracy = overall_accuracy
        torch.save(model.state_dict(), "../checkpoints/CIFRA10/best_model.pth")
        print(f"保存最佳模型！准确率：{best_accuracy:.2%}")

    print()

writer.close()

print(f"🎉 训练完成！最佳准确率：{best_accuracy:.2%}")
print(f"模型已保存到 ../checkpoints/ 目录")
# Out:
# -------第1轮训练开始-------
# 训练100个batch耗时：1.0568673610687256秒
# 训练次数：100， Loss：2.2916347980499268
# 训练100个batch耗时：1.9452755451202393秒
# 训练次数：200， Loss：2.2843587398529053
# 训练100个batch耗时：3.2109334468841553秒
# 训练次数：300， Loss：2.265637159347534
# 训练100个batch耗时：4.203899145126343秒
# 训练次数：400， Loss：2.193816900253296
# 训练100个batch耗时：5.0983195304870605秒
# 训练次数：500， Loss：2.141592264175415
# 训练100个batch耗时：6.046863079071045秒
# 训练次数：600， Loss：2.0545973777770996
# 训练100个batch耗时：6.990116357803345秒
# 训练次数：700， Loss：2.003502607345581
# 第 1 轮训练，平均 Loss：2.1802
# 第 1 轮测试，平均 Loss：2.0216，准确率：26.57%
# 保存最佳模型！准确率：26.57%
#
# -------第2轮训练开始-------
# 训练100个batch耗时：8.865328788757324秒
# 训练次数：800， Loss：1.8876079320907593
# 训练100个batch耗时：9.706599950790405秒
# 训练次数：900， Loss：1.850776195526123
# 训练100个batch耗时：10.521820783615112秒
# 训练次数：1000， Loss：1.921422004699707
# 训练100个batch耗时：11.427802801132202秒
# 训练次数：1100， Loss：1.9691129922866821
# 训练100个batch耗时：13.295053958892822秒
# 训练次数：1200， Loss：1.6913763284683228
# 训练100个batch耗时：15.294424772262573秒
# 训练次数：1300， Loss：1.6686904430389404
# 训练100个batch耗时：17.34062933921814秒
# 训练次数：1400， Loss：1.736670732498169
# 训练100个batch耗时：19.390711307525635秒
# 训练次数：1500， Loss：1.7930227518081665
# 第 2 轮训练，平均 Loss：1.8475
# 第 2 轮测试，平均 Loss：1.8754，准确率：33.03%
# 保存最佳模型！准确率：33.03%
#
# -------第3轮训练开始-------
# 训练100个batch耗时：23.09884762763977秒
# 训练次数：1600， Loss：1.7483476400375366
# 训练100个batch耗时：25.31014585494995秒
# 训练次数：1700， Loss：1.6375160217285156
# 训练100个batch耗时：28.214811086654663秒
# 训练次数：1800， Loss：1.9395095109939575
# 训练100个batch耗时：29.276867389678955秒
# 训练次数：1900， Loss：1.7255258560180664
# 训练100个batch耗时：33.969871044158936秒
# 训练次数：2000， Loss：1.895188331604004
# 训练100个batch耗时：34.92201852798462秒
# 训练次数：2100， Loss：1.5009061098098755
# 训练100个batch耗时：35.83149862289429秒
# 训练次数：2200， Loss：1.4697552919387817
# 训练100个batch耗时：36.78295922279358秒
# 训练次数：2300， Loss：1.7766032218933105
# 第 3 轮训练，平均 Loss：1.6578
# 第 3 轮测试，平均 Loss：1.6845，准确率：38.58%
# 保存最佳模型！准确率：38.58%
#
# -------第4轮训练开始-------
# 训练100个batch耗时：38.839216470718384秒
# 训练次数：2400， Loss：1.7123221158981323
# 训练100个batch耗时：39.768639087677秒
# 训练次数：2500， Loss：1.3608760833740234
# 训练100个batch耗时：40.74488544464111秒
# 训练次数：2600， Loss：1.5837613344192505
# 训练100个batch耗时：41.65440583229065秒
# 训练次数：2700， Loss：1.652382254600525
# 训练100个batch耗时：42.6877875328064秒
# 训练次数：2800， Loss：1.4507912397384644
# 训练100个batch耗时：43.756876707077026秒
# 训练次数：2900， Loss：1.5888867378234863
# 训练100个batch耗时：46.09405469894409秒
# 训练次数：3000， Loss：1.372881293296814
# 训练100个batch耗时：47.25975036621094秒
# 训练次数：3100， Loss：1.5123419761657715
# 第 4 轮训练，平均 Loss：1.5383
# 第 4 轮测试，平均 Loss：1.6545，准确率：40.12%
# 保存最佳模型！准确率：40.12%
#
# -------第5轮训练开始-------
# 训练100个batch耗时：50.32902979850769秒
# 训练次数：3200， Loss：1.3260215520858765
# 训练100个batch耗时：52.183534383773804秒
# 训练次数：3300， Loss：1.4906952381134033
# 训练100个batch耗时：53.47388005256653秒
# 训练次数：3400， Loss：1.4433519840240479
# 训练100个batch耗时：54.62815833091736秒
# 训练次数：3500， Loss：1.541270136833191
# 训练100个batch耗时：57.6108193397522秒
# 训练次数：3600， Loss：1.5670242309570312
# 训练100个batch耗时：59.81194615364075秒
# 训练次数：3700， Loss：1.3183220624923706
# 训练100个batch耗时：61.78078103065491秒
# 训练次数：3800， Loss：1.2546995878219604
# 训练100个batch耗时：64.07455229759216秒
# 训练次数：3900， Loss：1.450208067893982
# 第 5 轮训练，平均 Loss：1.4537
# 第 5 轮测试，平均 Loss：1.5838，准确率：42.55%
# 保存第5轮次的模型
# 保存最佳模型！准确率：42.55%
#
# -------第6轮训练开始-------
# 训练100个batch耗时：66.28732490539551秒
# 训练次数：4000， Loss：1.382733702659607
# 训练100个batch耗时：70.19096779823303秒
# 训练次数：4100， Loss：1.4180752038955688
# 训练100个batch耗时：72.170645236969秒
# 训练次数：4200， Loss：1.5392004251480103
# 训练100个batch耗时：74.34437489509583秒
# 训练次数：4300， Loss：1.199927568435669
# 训练100个batch耗时：76.68182468414307秒
# 训练次数：4400， Loss：1.1567410230636597
# 训练100个batch耗时：79.2304790019989秒
# 训练次数：4500， Loss：1.3751219511032104
# 训练100个batch耗时：81.44060850143433秒
# 训练次数：4600， Loss：1.4050612449645996
# 第 6 轮训练，平均 Loss：1.3838
# 第 6 轮测试，平均 Loss：1.5180，准确率：44.86%
# 保存最佳模型！准确率：44.86%
#
# -------第7轮训练开始-------
# 训练100个batch耗时：84.47704291343689秒
# 训练次数：4700， Loss：1.3517314195632935
# 训练100个batch耗时：86.47442126274109秒
# 训练次数：4800， Loss：1.4373152256011963
# 训练100个batch耗时：88.7589328289032秒
# 训练次数：4900， Loss：1.4025208950042725
# 训练100个batch耗时：90.78734683990479秒
# 训练次数：5000， Loss：1.4485102891921997
# 训练100个batch耗时：92.2977728843689秒
# 训练次数：5100， Loss：1.0067585706710815
# 训练100个batch耗时：93.6120810508728秒
# 训练次数：5200， Loss：1.2977102994918823
# 训练100个batch耗时：94.63431859016418秒
# 训练次数：5300， Loss：1.164923071861267
# 训练100个batch耗时：95.82804346084595秒
# 训练次数：5400， Loss：1.3712742328643799
# 第 7 轮训练，平均 Loss：1.3202
# 第 7 轮测试，平均 Loss：1.4466，准确率：47.75%
# 保存最佳模型！准确率：47.75%
#
# -------第8轮训练开始-------
# 训练100个batch耗时：99.15102076530457秒
# 训练次数：5500， Loss：1.2042053937911987
# 训练100个batch耗时：101.09263634681702秒
# 训练次数：5600， Loss：1.1945611238479614
# 训练100个batch耗时：102.33598327636719秒
# 训练次数：5700， Loss：1.2212104797363281
# 训练100个batch耗时：103.45249676704407秒
# 训练次数：5800， Loss：1.2222713232040405
# 训练100个batch耗时：104.43755578994751秒
# 训练次数：5900， Loss：1.334754228591919
# 训练100个batch耗时：105.44765782356262秒
# 训练次数：6000， Loss：1.578019380569458
# 训练100个batch耗时：106.39483451843262秒
# 训练次数：6100， Loss：1.0336182117462158
# 训练100个batch耗时：107.2864420413971秒
# 训练次数：6200， Loss：1.115578055381775
# 第 8 轮训练，平均 Loss：1.2600
# 第 8 轮测试，平均 Loss：1.3572，准确率：51.25%
# 保存最佳模型！准确率：51.25%
#
# -------第9轮训练开始-------
# 训练100个batch耗时：109.1463508605957秒
# 训练次数：6300， Loss：1.4255839586257935
# 训练100个batch耗时：110.01529216766357秒
# 训练次数：6400， Loss：1.1244341135025024
# 训练100个batch耗时：111.02243685722351秒
# 训练次数：6500， Loss：1.5024009943008423
# 训练100个batch耗时：112.0514132976532秒
# 训练次数：6600， Loss：1.074817180633545
# 训练100个batch耗时：113.18414282798767秒
# 训练次数：6700， Loss：1.0603463649749756
# 训练100个batch耗时：114.11819529533386秒
# 训练次数：6800， Loss：1.1399927139282227
# 训练100个batch耗时：115.09127354621887秒
# 训练次数：6900， Loss：1.1031993627548218
# 训练100个batch耗时：116.05394768714905秒
# 训练次数：7000， Loss：0.9341824054718018
# 第 9 轮训练，平均 Loss：1.2036
# 第 9 轮测试，平均 Loss：1.2876，准确率：54.36%
# 保存最佳模型！准确率：54.36%
#
# -------第10轮训练开始-------
# 训练100个batch耗时：118.02814078330994秒
# 训练次数：7100， Loss：1.2058197259902954
# 训练100个batch耗时：119.11126232147217秒
# 训练次数：7200， Loss：0.9691694974899292
# 训练100个batch耗时：120.04350852966309秒
# 训练次数：7300， Loss：1.114890694618225
# 训练100个batch耗时：121.09871864318848秒
# 训练次数：7400， Loss：0.831011176109314
# 训练100个batch耗时：122.06493496894836秒
# 训练次数：7500， Loss：1.1861076354980469
# 训练100个batch耗时：122.98867177963257秒
# 训练次数：7600， Loss：1.2779804468154907
# 训练100个batch耗时：123.9049801826477秒
# 训练次数：7700， Loss：0.8562405109405518
# 训练100个batch耗时：125.75234627723694秒
# 训练次数：7800， Loss：1.25662362575531
# 第 10 轮训练，平均 Loss：1.1516
# 第 10 轮测试，平均 Loss：1.2396，准确率：55.91%
# 保存第10轮次的模型
# 保存最佳模型！准确率：55.91%
#
# -------第11轮训练开始-------
# 训练100个batch耗时：127.91347861289978秒
# 训练次数：7900， Loss：1.3745139837265015
# 训练100个batch耗时：128.7363166809082秒
# 训练次数：8000， Loss：1.0696133375167847
# 训练100个batch耗时：129.6375789642334秒
# 训练次数：8100， Loss：0.9714431166648865
# 训练100个batch耗时：130.66002011299133秒
# 训练次数：8200， Loss：1.2518807649612427
# 训练100个batch耗时：131.86417293548584秒
# 训练次数：8300， Loss：1.2623071670532227
# 训练100个batch耗时：132.74337220191956秒
# 训练次数：8400， Loss：1.0092085599899292
# 训练100个batch耗时：133.69392323493958秒
# 训练次数：8500， Loss：1.1867433786392212
# 训练100个batch耗时：134.97237420082092秒
# 训练次数：8600， Loss：0.9017012715339661
# 第 11 轮训练，平均 Loss：1.1045
# 第 11 轮测试，平均 Loss：1.2029，准确率：57.22%
# 保存最佳模型！准确率：57.22%
#
# -------第12轮训练开始-------
# 训练100个batch耗时：137.9634609222412秒
# 训练次数：8700， Loss：1.1732916831970215
# 训练100个batch耗时：140.17316675186157秒
# 训练次数：8800， Loss：1.3646146059036255
# 训练100个batch耗时：142.18540143966675秒
# 训练次数：8900， Loss：1.008600115776062
# 训练100个batch耗时：144.33919095993042秒
# 训练次数：9000， Loss：1.2012985944747925
# 训练100个batch耗时：146.5120770931244秒
# 训练次数：9100， Loss：1.0635371208190918
# 训练100个batch耗时：148.86342597007751秒
# 训练次数：9200， Loss：1.038425087928772
# 训练100个batch耗时：151.2060031890869秒
# 训练次数：9300， Loss：1.1098859310150146
# 第 12 轮训练，平均 Loss：1.0621
# 第 12 轮测试，平均 Loss：1.1728，准确率：58.38%
# 保存最佳模型！准确率：58.38%
#
# -------第13轮训练开始-------
# 训练100个batch耗时：154.1195273399353秒
# 训练次数：9400， Loss：0.8428776860237122
# 训练100个batch耗时：155.0814344882965秒
# 训练次数：9500， Loss：1.356109857559204
# 训练100个batch耗时：156.75886154174805秒
# 训练次数：9600， Loss：1.1316089630126953
# 训练100个batch耗时：158.3908371925354秒
# 训练次数：9700， Loss：1.093202829360962
# 训练100个batch耗时：159.50968146324158秒
# 训练次数：9800， Loss：1.0217649936676025
# 训练100个batch耗时：160.53573894500732秒
# 训练次数：9900， Loss：1.046515941619873
# 训练100个batch耗时：161.63587737083435秒
# 训练次数：10000， Loss：0.9469702243804932
# 训练100个batch耗时：162.49712586402893秒
# 训练次数：10100， Loss：0.9022366404533386
# 第 13 轮训练，平均 Loss：1.0239
# 第 13 轮测试，平均 Loss：1.1486，准确率：59.43%
# 保存最佳模型！准确率：59.43%
#
# -------第14轮训练开始-------
# 训练100个batch耗时：165.08741235733032秒
# 训练次数：10200， Loss：0.7910645008087158
# 训练100个batch耗时：165.97067070007324秒
# 训练次数：10300， Loss：0.9567686319351196
# 训练100个batch耗时：166.89101600646973秒
# 训练次数：10400， Loss：1.1962560415267944
# 训练100个batch耗时：167.78359723091125秒
# 训练次数：10500， Loss：0.7773211598396301
# 训练100个batch耗时：168.6901934146881秒
# 训练次数：10600， Loss：0.9358198642730713
# 训练100个batch耗时：169.5257203578949秒
# 训练次数：10700， Loss：0.7281306385993958
# 训练100个batch耗时：170.515563249588秒
# 训练次数：10800， Loss：0.8457949757575989
# 训练100个batch耗时：171.61169481277466秒
# 训练次数：10900， Loss：0.9531131386756897
# 第 14 轮训练，平均 Loss：0.9895
# 第 14 轮测试，平均 Loss：1.1266，准确率：60.46%
# 保存最佳模型！准确率：60.46%
#
# -------第15轮训练开始-------
# 训练100个batch耗时：173.51056170463562秒
# 训练次数：11000， Loss：1.0810692310333252
# 训练100个batch耗时：174.35801148414612秒
# 训练次数：11100， Loss：0.8999029994010925
# 训练100个batch耗时：175.25909399986267秒
# 训练次数：11200， Loss：0.9745975732803345
# 训练100个batch耗时：177.09129643440247秒
# 训练次数：11300， Loss：1.1425741910934448
# 训练100个batch耗时：178.02400994300842秒
# 训练次数：11400， Loss：0.7511640191078186
# 训练100个batch耗时：179.05329656600952秒
# 训练次数：11500， Loss：1.117929458618164
# 训练100个batch耗时：180.07335782051086秒
# 训练次数：11600， Loss：0.9242494106292725
# 训练100个batch耗时：181.0661277770996秒
# 训练次数：11700， Loss：0.9343392252922058
# 第 15 轮训练，平均 Loss：0.9580
# 第 15 轮测试，平均 Loss：1.1030，准确率：61.35%
# 保存第15轮次的模型
# 保存最佳模型！准确率：61.35%
#
# -------第16轮训练开始-------
# 训练100个batch耗时：182.9150881767273秒
# 训练次数：11800， Loss：0.8261049389839172
# 训练100个batch耗时：183.87531757354736秒
# 训练次数：11900， Loss：0.9618774056434631
# 训练100个batch耗时：184.72597408294678秒
# 训练次数：12000， Loss：0.8505967259407043
# 训练100个batch耗时：185.5062382221222秒
# 训练次数：12100， Loss：0.9403000473976135
# 训练100个batch耗时：186.40482783317566秒
# 训练次数：12200， Loss：0.973649799823761
# 训练100个batch耗时：188.1524693965912秒
# 训练次数：12300， Loss：0.8547680974006653
# 训练100个batch耗时：189.02932000160217秒
# 训练次数：12400， Loss：0.8881281614303589
# 训练100个batch耗时：189.84906315803528秒
# 训练次数：12500， Loss：0.6724810600280762
# 第 16 轮训练，平均 Loss：0.9285
# 第 16 轮测试，平均 Loss：1.0850，准确率：62.19%
# 保存最佳模型！准确率：62.19%
#
# -------第17轮训练开始-------
# 训练100个batch耗时：191.48453307151794秒
# 训练次数：12600， Loss：0.7917578816413879
# 训练100个batch耗时：192.376868724823秒
# 训练次数：12700， Loss：0.8922992944717407
# 训练100个batch耗时：193.30790495872498秒
# 训练次数：12800， Loss：0.7917913794517517
# 训练100个batch耗时：194.18539309501648秒
# 训练次数：12900， Loss：1.1991418600082397
# 训练100个batch耗时：195.0837163925171秒
# 训练次数：13000， Loss：1.0863538980484009
# 训练100个batch耗时：195.94571089744568秒
# 训练次数：13100， Loss：0.6685330271720886
# 训练100个batch耗时：197.83203268051147秒
# 训练次数：13200， Loss：0.788799524307251
# 第 17 轮训练，平均 Loss：0.9007
# 第 17 轮测试，平均 Loss：1.0635，准确率：63.32%
# 保存最佳模型！准确率：63.32%
#
# -------第18轮训练开始-------
# 训练100个batch耗时：199.69738817214966秒
# 训练次数：13300， Loss：0.9709010720252991
# 训练100个batch耗时：200.82773542404175秒
# 训练次数：13400， Loss：0.6824871897697449
# 训练100个batch耗时：201.91452407836914秒
# 训练次数：13500， Loss：0.8458337783813477
# 训练100个batch耗时：203.15946340560913秒
# 训练次数：13600， Loss：1.226462721824646
# 训练100个batch耗时：204.22745037078857秒
# 训练次数：13700， Loss：0.791844367980957
# 训练100个batch耗时：205.13533735275269秒
# 训练次数：13800， Loss：0.9661890268325806
# 训练100个batch耗时：206.37995290756226秒
# 训练次数：13900， Loss：0.6931432485580444
# 训练100个batch耗时：208.85927081108093秒
# 训练次数：14000， Loss：0.8831130266189575
# 第 18 轮训练，平均 Loss：0.8746
# 第 18 轮测试，平均 Loss：1.0496，准确率：63.92%
# 保存最佳模型！准确率：63.92%
#
# -------第19轮训练开始-------
# 训练100个batch耗时：210.68319749832153秒
# 训练次数：14100， Loss：0.9988256692886353
# 训练100个batch耗时：211.57570838928223秒
# 训练次数：14200， Loss：0.8438287973403931
# 训练100个batch耗时：212.41197037696838秒
# 训练次数：14300， Loss：0.8892475962638855
# 训练100个batch耗时：213.35114693641663秒
# 训练次数：14400， Loss：0.9499816298484802
# 训练100个batch耗时：214.15599083900452秒
# 训练次数：14500， Loss：0.8617191314697266
# 训练100个batch耗时：215.9394028186798秒
# 训练次数：14600， Loss：1.0515135526657104
# 训练100个batch耗时：218.1086709499359秒
# 训练次数：14700， Loss：0.7735769748687744
# 训练100个batch耗时：219.69043850898743秒
# 训练次数：14800， Loss：1.206221580505371
# 第 19 轮训练，平均 Loss：0.8498
# 第 19 轮测试，平均 Loss：1.0394，准确率：64.58%
# 保存最佳模型！准确率：64.58%
#
# -------第20轮训练开始-------
# 训练100个batch耗时：221.25681138038635秒
# 训练次数：14900， Loss：0.5457581281661987
# 训练100个batch耗时：222.16629767417908秒
# 训练次数：15000， Loss：0.9432527422904968
# 训练100个batch耗时：223.03868913650513秒
# 训练次数：15100， Loss：0.7340261936187744
# 训练100个batch耗时：223.98053407669067秒
# 训练次数：15200， Loss：0.9584964513778687
# 训练100个batch耗时：224.76141738891602秒
# 训练次数：15300， Loss：0.6802476644515991
# 训练100个batch耗时：225.63950324058533秒
# 训练次数：15400， Loss：0.8693326711654663
# 训练100个batch耗时：226.73379778862秒
# 训练次数：15500， Loss：0.837848961353302
# 训练100个batch耗时：227.7951695919037秒
# 训练次数：15600， Loss：0.8868000507354736
# 第 20 轮训练，平均 Loss：0.8263
# 第 20 轮测试，平均 Loss：1.0304，准确率：65.05%
# 保存第20轮次的模型
# 保存最佳模型！准确率：65.05%
#
# 🎉 训练完成！最佳准确率：65.05%
# 模型已保存到 ../checkpoints/ 目录

# %%
# 定义训练的设备
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 创建网络模型
model = Model_CIFAR()
model.to(device)

# 创建损失函数
loss_fn = nn.CrossEntropyLoss()
loss_fn.to(device)

# 定义优化器
learning_rate = 2e-2
optimizer = torch.optim.SGD(params=model.parameters(), lr=learning_rate)

# 设置训练网络参数
epoch = 20 # 训练轮次
total_train_step = 0 # 记录训练次数
total_test_step = 0 # 记录测试次数
best_accuracy = 0.0 # 记录最佳准确率

# 添加tensorboard
writer = SummaryWriter('../logs/logs_train')

start_time = time.time()
for i in range(epoch):
    print(f"-------第{i+1}轮训练开始-------")

    # 训练开始
    model.train()
    total_train_loss = 0.0
    avg_train_loss = 0.0
    for data in train_dataloader:
        imgs, targets = data
        imgs = imgs.to(device)
        targets = targets.to(device)
        output = model(imgs)
        loss = loss_fn(output, targets)
        # 优化器优化模型
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_train_step += 1
        total_train_loss += loss.item()

        # 每100个batch打印一次
        if total_train_step % 100 == 0:
            end_time = time.time()
            print(f"训练100个batch耗时：{end_time - start_time}秒")
            print(f"训练次数：{total_train_step}， Loss：{loss.item()}")
            writer.add_scalar(tag='train_loss', scalar_value=loss.item(), global_step=total_train_step)

    # 打印每个epoch的平均loss
    avg_train_loss = total_train_loss / len(train_dataloader)
    print(f"第 {i+1} 轮训练，平均 Loss：{avg_train_loss:.4f}")

    # 测试阶段
    model.eval()
    total_test_loss= 0.0
    total_accuracy = 0.0
    avg_test_loss = 0.0

    with torch.no_grad(): # 测试时候不需要计算梯度
        for data in test_dataloader:
            imgs, targets = data
            imgs = imgs.to(device)
            targets = targets.to(device)
            outputs = model(imgs)
            loss = loss_fn(outputs, targets)

            total_test_loss += loss.item()

            # 计算准确率
            accuracy = (outputs.argmax(1) == targets).sum()
            total_accuracy += accuracy

    avg_test_loss = total_test_loss / len(test_dataloader)
    overall_accuracy = total_accuracy / test_data_size
    print(f"第 {i+1} 轮测试，平均 Loss：{avg_test_loss:.4f}，准确率：{overall_accuracy:.2%}")

    writer.add_scalar(tag='test_loss', scalar_value=avg_test_loss, global_step=total_test_step)

    total_test_step += 1

    # 模型保存：每5个epoch保存一次模型
    if (i+1)%5 == 0:
        torch.save(model.state_dict(), f"../checkpoints/CIFRA10/model_epoch_{i+1}.pth")
        print(f"保存第{i+1}轮次的模型")

    # 最佳模型保存
    if overall_accuracy > best_accuracy:
        best_accuracy = overall_accuracy
        torch.save(model.state_dict(), "../checkpoints/CIFRA10/best_model.pth")
        print(f"保存最佳模型！准确率：{best_accuracy:.2%}")

    print()

writer.close()

print(f"🎉 训练完成！最佳准确率：{best_accuracy:.2%}")
print(f"模型已保存到 ../checkpoints/ 目录")
# Out:
# -------第1轮训练开始-------
# 训练100个batch耗时：0.3448209762573242秒
# 训练次数：100， Loss：2.2559256553649902
# 训练100个batch耗时：0.6811919212341309秒
# 训练次数：200， Loss：2.1533145904541016
# 训练100个batch耗时：1.00048828125秒
# 训练次数：300， Loss：2.041503429412842
# 训练100个batch耗时：1.3154971599578857秒
# 训练次数：400， Loss：1.9673103094100952
# 训练100个batch耗时：1.6318204402923584秒
# 训练次数：500， Loss：1.8660335540771484
# 训练100个batch耗时：1.9530961513519287秒
# 训练次数：600， Loss：1.89186429977417
# 训练100个batch耗时：2.2703945636749268秒
# 训练次数：700， Loss：1.8362712860107422
# 第 1 轮训练，平均 Loss：1.9974
# 第 1 轮测试，平均 Loss：1.9683，准确率：29.59%
# 保存最佳模型！准确率：29.59%
#
# -------第2轮训练开始-------
# 训练100个batch耗时：2.979355812072754秒
# 训练次数：800， Loss：1.6776424646377563
# 训练100个batch耗时：3.2981481552124023秒
# 训练次数：900， Loss：1.5908658504486084
# 训练100个batch耗时：3.615436315536499秒
# 训练次数：1000， Loss：1.6286003589630127
# 训练100个batch耗时：3.933281183242798秒
# 训练次数：1100， Loss：1.874021291732788
# 训练100个batch耗时：4.250903129577637秒
# 训练次数：1200， Loss：1.6056119203567505
# 训练100个batch耗时：4.575193643569946秒
# 训练次数：1300， Loss：1.4091897010803223
# 训练100个batch耗时：4.896306276321411秒
# 训练次数：1400， Loss：1.5087876319885254
# 训练100个batch耗时：5.2176148891448975秒
# 训练次数：1500， Loss：1.6029918193817139
# 第 2 轮训练，平均 Loss：1.6392
# 第 2 轮测试，平均 Loss：1.6844，准确率：39.10%
# 保存最佳模型！准确率：39.10%
#
# -------第3轮训练开始-------
# 训练100个batch耗时：5.918394565582275秒
# 训练次数：1600， Loss：1.440347671508789
# 训练100个batch耗时：6.233733654022217秒
# 训练次数：1700， Loss：1.4632495641708374
# 训练100个batch耗时：6.550553560256958秒
# 训练次数：1800， Loss：1.7186440229415894
# 训练100个batch耗时：6.867551803588867秒
# 训练次数：1900， Loss：1.5428193807601929
# 训练100个batch耗时：7.1887366771698秒
# 训练次数：2000， Loss：1.7819435596466064
# 训练100个batch耗时：7.505306959152222秒
# 训练次数：2100， Loss：1.3035521507263184
# 训练100个batch耗时：7.827192783355713秒
# 训练次数：2200， Loss：1.2223412990570068
# 训练100个batch耗时：8.151936054229736秒
# 训练次数：2300， Loss：1.544271469116211
# 第 3 轮训练，平均 Loss：1.4728
# 第 3 轮测试，平均 Loss：1.6582，准确率：40.58%
# 保存最佳模型！准确率：40.58%
#
# -------第4轮训练开始-------
# 训练100个batch耗时：8.865776062011719秒
# 训练次数：2400， Loss：1.5067487955093384
# 训练100个batch耗时：9.184004783630371秒
# 训练次数：2500， Loss：1.1350979804992676
# 训练100个batch耗时：9.507299661636353秒
# 训练次数：2600， Loss：1.4125099182128906
# 训练100个batch耗时：9.828973770141602秒
# 训练次数：2700， Loss：1.452463150024414
# 训练100个batch耗时：10.146968841552734秒
# 训练次数：2800， Loss：1.3173778057098389
# 训练100个batch耗时：10.469083309173584秒
# 训练次数：2900， Loss：1.4033504724502563
# 训练100个batch耗时：10.791090726852417秒
# 训练次数：3000， Loss：1.1310784816741943
# 训练100个batch耗时：11.112557172775269秒
# 训练次数：3100， Loss：1.369031310081482
# 第 4 轮训练，平均 Loss：1.3451
# 第 4 轮测试，平均 Loss：1.4924，准确率：46.48%
# 保存最佳模型！准确率：46.48%
#
# -------第5轮训练开始-------
# 训练100个batch耗时：11.826212167739868秒
# 训练次数：3200， Loss：1.0979368686676025
# 训练100个batch耗时：12.146835565567017秒
# 训练次数：3300， Loss：1.2437806129455566
# 训练100个batch耗时：12.464879274368286秒
# 训练次数：3400， Loss：1.1593812704086304
# 训练100个batch耗时：12.786626100540161秒
# 训练次数：3500， Loss：1.1999224424362183
# 训练100个batch耗时：13.108227729797363秒
# 训练次数：3600， Loss：1.265837550163269
# 训练100个batch耗时：13.425610065460205秒
# 训练次数：3700， Loss：1.1838171482086182
# 训练100个batch耗时：13.743027210235596秒
# 训练次数：3800， Loss：1.2102075815200806
# 训练100个batch耗时：14.063188552856445秒
# 训练次数：3900， Loss：1.235065221786499
# 第 5 轮训练，平均 Loss：1.2330
# 第 5 轮测试，平均 Loss：1.3339，准确率：52.11%
# 保存第5轮次的模型
# 保存最佳模型！准确率：52.11%
#
# -------第6轮训练开始-------
# 训练100个batch耗时：14.779219150543213秒
# 训练次数：4000， Loss：1.235844612121582
# 训练100个batch耗时：15.09757375717163秒
# 训练次数：4100， Loss：1.2609968185424805
# 训练100个batch耗时：15.417177438735962秒
# 训练次数：4200， Loss：1.3030602931976318
# 训练100个batch耗时：15.739049196243286秒
# 训练次数：4300， Loss：1.0188562870025635
# 训练100个batch耗时：16.05714440345764秒
# 训练次数：4400， Loss：0.8127490282058716
# 训练100个batch耗时：16.37518882751465秒
# 训练次数：4500， Loss：1.2519793510437012
# 训练100个batch耗时：16.693614959716797秒
# 训练次数：4600， Loss：1.1785333156585693
# 第 6 轮训练，平均 Loss：1.1415
# 第 6 轮测试，平均 Loss：1.2596，准确率：54.92%
# 保存最佳模型！准确率：54.92%
#
# -------第7轮训练开始-------
# 训练100个batch耗时：17.398285627365112秒
# 训练次数：4700， Loss：1.0342814922332764
# 训练100个batch耗时：17.716014623641968秒
# 训练次数：4800， Loss：1.3080015182495117
# 训练100个batch耗时：18.03511333465576秒
# 训练次数：4900， Loss：1.1798810958862305
# 训练100个batch耗时：18.35870671272278秒
# 训练次数：5000， Loss：1.216681718826294
# 训练100个batch耗时：18.67583966255188秒
# 训练次数：5100， Loss：0.8055782318115234
# 训练100个batch耗时：18.995943784713745秒
# 训练次数：5200， Loss：1.0541503429412842
# 训练100个batch耗时：19.316174507141113秒
# 训练次数：5300， Loss：0.8987976908683777
# 训练100个batch耗时：19.635316371917725秒
# 训练次数：5400， Loss：1.00175940990448
# 第 7 轮训练，平均 Loss：1.0693
# 第 7 轮测试，平均 Loss：1.2253，准确率：56.56%
# 保存最佳模型！准确率：56.56%
#
# -------第8轮训练开始-------
# 训练100个batch耗时：20.347865343093872秒
# 训练次数：5500， Loss：1.1188724040985107
# 训练100个batch耗时：20.667898654937744秒
# 训练次数：5600， Loss：0.9116983413696289
# 训练100个batch耗时：20.988569974899292秒
# 训练次数：5700， Loss：0.9263124465942383
# 训练100个batch耗时：21.30927062034607秒
# 训练次数：5800， Loss：0.8860340118408203
# 训练100个batch耗时：21.630006313323975秒
# 训练次数：5900， Loss：1.1732892990112305
# 训练100个batch耗时：21.948697566986084秒
# 训练次数：6000， Loss：1.2255563735961914
# 训练100个batch耗时：22.271485328674316秒
# 训练次数：6100， Loss：0.8321956396102905
# 训练100个batch耗时：22.593254327774048秒
# 训练次数：6200， Loss：0.8963229656219482
# 第 8 轮训练，平均 Loss：1.0111
# 第 8 轮测试，平均 Loss：1.1841，准确率：58.58%
# 保存最佳模型！准确率：58.58%
#
# -------第9轮训练开始-------
# 训练100个batch耗时：23.310816526412964秒
# 训练次数：6300， Loss：1.1377689838409424
# 训练100个batch耗时：23.627391576766968秒
# 训练次数：6400， Loss：0.9085274338722229
# 训练100个batch耗时：23.942554235458374秒
# 训练次数：6500， Loss：1.2238701581954956
# 训练100个batch耗时：24.262709617614746秒
# 训练次数：6600， Loss：0.9256402254104614
# 训练100个batch耗时：24.58647346496582秒
# 训练次数：6700， Loss：0.857285737991333
# 训练100个batch耗时：24.90695285797119秒
# 训练次数：6800， Loss：0.8111723065376282
# 训练100个batch耗时：25.227733850479126秒
# 训练次数：6900， Loss：0.7553758025169373
# 训练100个batch耗时：25.54884696006775秒
# 训练次数：7000， Loss：0.5271947979927063
# 第 9 轮训练，平均 Loss：0.9612
# 第 9 轮测试，平均 Loss：1.1582，准确率：60.03%
# 保存最佳模型！准确率：60.03%
#
# -------第10轮训练开始-------
# 训练100个batch耗时：26.257615089416504秒
# 训练次数：7100， Loss：0.9050309658050537
# 训练100个batch耗时：26.575272798538208秒
# 训练次数：7200， Loss：0.7252156734466553
# 训练100个batch耗时：26.89403223991394秒
# 训练次数：7300， Loss：0.8179947137832642
# 训练100个batch耗时：27.21290111541748秒
# 训练次数：7400， Loss：0.604062020778656
# 训练100个batch耗时：27.53182864189148秒
# 训练次数：7500， Loss：0.9490984678268433
# 训练100个batch耗时：27.84966254234314秒
# 训练次数：7600， Loss：1.1048104763031006
# 训练100个batch耗时：28.173845052719116秒
# 训练次数：7700， Loss：0.7663314342498779
# 训练100个batch耗时：28.494993209838867秒
# 训练次数：7800， Loss：1.03353750705719
# 第 10 轮训练，平均 Loss：0.9167
# 第 10 轮测试，平均 Loss：1.1370，准确率：61.00%
# 保存第10轮次的模型
# 保存最佳模型！准确率：61.00%
#
# -------第11轮训练开始-------
# 训练100个batch耗时：29.20809578895569秒
# 训练次数：7900， Loss：1.0359777212142944
# 训练100个batch耗时：29.521336793899536秒
# 训练次数：8000， Loss：0.7921167612075806
# 训练100个batch耗时：29.836496829986572秒
# 训练次数：8100， Loss：0.768717885017395
# 训练100个batch耗时：30.156204223632812秒
# 训练次数：8200， Loss：0.9754773378372192
# 训练100个batch耗时：30.475610971450806秒
# 训练次数：8300， Loss：1.0938103199005127
# 训练100个batch耗时：30.79405117034912秒
# 训练次数：8400， Loss：0.8582112193107605
# 训练100个batch耗时：31.111330032348633秒
# 训练次数：8500， Loss：0.9077031016349792
# 训练100个batch耗时：31.42881488800049秒
# 训练次数：8600， Loss：0.525843620300293
# 第 11 轮训练，平均 Loss：0.8761
# 第 11 轮测试，平均 Loss：1.1183，准确率：61.78%
# 保存最佳模型！准确率：61.78%
#
# -------第12轮训练开始-------
# 训练100个batch耗时：32.15137982368469秒
# 训练次数：8700， Loss：0.912869393825531
# 训练100个batch耗时：32.47085452079773秒
# 训练次数：8800， Loss：0.9137148857116699
# 训练100个batch耗时：32.78702235221863秒
# 训练次数：8900， Loss：0.8661484718322754
# 训练100个batch耗时：33.10296988487244秒
# 训练次数：9000， Loss：0.9389258027076721
# 训练100个batch耗时：33.42261624336243秒
# 训练次数：9100， Loss：0.787638783454895
# 训练100个batch耗时：33.74179172515869秒
# 训练次数：9200， Loss：0.8899340629577637
# 训练100个batch耗时：34.05636215209961秒
# 训练次数：9300， Loss：0.9096259474754333
# 第 12 轮训练，平均 Loss：0.8378
# 第 12 轮测试，平均 Loss：1.1136，准确率：62.47%
# 保存最佳模型！准确率：62.47%
#
# -------第13轮训练开始-------
# 训练100个batch耗时：34.75982594490051秒
# 训练次数：9400， Loss：0.6918870210647583
# 训练100个batch耗时：35.073989152908325秒
# 训练次数：9500， Loss：1.0394887924194336
# 训练100个batch耗时：35.388145446777344秒
# 训练次数：9600， Loss：0.955815315246582
# 训练100个batch耗时：35.7034432888031秒
# 训练次数：9700， Loss：0.8365427255630493
# 训练100个batch耗时：36.02926230430603秒
# 训练次数：9800， Loss：0.726959228515625
# 训练100个batch耗时：36.34434485435486秒
# 训练次数：9900， Loss：0.6866739988327026
# 训练100个batch耗时：36.66972517967224秒
# 训练次数：10000， Loss：0.7175459861755371
# 训练100个batch耗时：36.984858989715576秒
# 训练次数：10100， Loss：0.7959513664245605
# 第 13 轮训练，平均 Loss：0.8017
# 第 13 轮测试，平均 Loss：1.1265，准确率：62.53%
# 保存最佳模型！准确率：62.53%
#
# -------第14轮训练开始-------
# 训练100个batch耗时：37.6879563331604秒
# 训练次数：10200， Loss：0.563173770904541
# 训练100个batch耗时：38.00476098060608秒
# 训练次数：10300， Loss：0.8147731423377991
# 训练100个batch耗时：38.345710039138794秒
# 训练次数：10400， Loss：1.0360610485076904
# 训练100个batch耗时：38.66827440261841秒
# 训练次数：10500， Loss：0.5532504320144653
# 训练100个batch耗时：38.98205852508545秒
# 训练次数：10600， Loss：0.6117521524429321
# 训练100个batch耗时：39.30319380760193秒
# 训练次数：10700， Loss：0.4484979510307312
# 训练100个batch耗时：39.623915672302246秒
# 训练次数：10800， Loss：0.7354089021682739
# 训练100个batch耗时：39.9425323009491秒
# 训练次数：10900， Loss：0.8198751211166382
# 第 14 轮训练，平均 Loss：0.7671
# 第 14 轮测试，平均 Loss：1.1305，准确率：62.93%
# 保存最佳模型！准确率：62.93%
#
# -------第15轮训练开始-------
# 训练100个batch耗时：40.64697980880737秒
# 训练次数：11000， Loss：0.7829838991165161
# 训练100个batch耗时：40.967077016830444秒
# 训练次数：11100， Loss：0.71123206615448
# 训练100个batch耗时：41.29163384437561秒
# 训练次数：11200， Loss：0.7651149034500122
# 训练100个batch耗时：41.606908082962036秒
# 训练次数：11300， Loss：0.8777778148651123
# 训练100个batch耗时：41.92166614532471秒
# 训练次数：11400， Loss：0.5720391273498535
# 训练100个batch耗时：42.237961530685425秒
# 训练次数：11500， Loss：0.8292876482009888
# 训练100个batch耗时：42.55695676803589秒
# 训练次数：11600， Loss：0.5960973501205444
# 训练100个batch耗时：42.87510704994202秒
# 训练次数：11700， Loss：0.677452802658081
# 第 15 轮训练，平均 Loss：0.7343
# 第 15 轮测试，平均 Loss：1.1846，准确率：61.85%
# 保存第15轮次的模型
#
# -------第16轮训练开始-------
# 训练100个batch耗时：43.577629804611206秒
# 训练次数：11800， Loss：0.5673947334289551
# 训练100个batch耗时：43.896399974823秒
# 训练次数：11900， Loss：0.9283369779586792
# 训练100个batch耗时：44.21426343917847秒
# 训练次数：12000， Loss：0.6568702459335327
# 训练100个batch耗时：44.52967166900635秒
# 训练次数：12100， Loss：0.721532940864563
# 训练100个batch耗时：44.844420194625854秒
# 训练次数：12200， Loss：0.7189111709594727
# 训练100个batch耗时：45.159709215164185秒
# 训练次数：12300， Loss：0.786914050579071
# 训练100个batch耗时：45.47675657272339秒
# 训练次数：12400， Loss：0.5935075283050537
# 训练100个batch耗时：45.79473042488098秒
# 训练次数：12500， Loss：0.45493096113204956
# 第 16 轮训练，平均 Loss：0.7029
# 第 16 轮测试，平均 Loss：1.2129，准确率：61.63%
#
# -------第17轮训练开始-------
# 训练100个batch耗时：46.498528480529785秒
# 训练次数：12600， Loss：0.5230674743652344
# 训练100个batch耗时：46.812074184417725秒
# 训练次数：12700， Loss：0.5597596168518066
# 训练100个batch耗时：47.12684655189514秒
# 训练次数：12800， Loss：0.5386404991149902
# 训练100个batch耗时：47.442028284072876秒
# 训练次数：12900， Loss：0.8927819728851318
# 训练100个batch耗时：47.75617980957031秒
# 训练次数：13000， Loss：0.8636555671691895
# 训练100个batch耗时：48.06883358955383秒
# 训练次数：13100， Loss：0.44671881198883057
# 训练100个batch耗时：48.38507127761841秒
# 训练次数：13200， Loss：0.5358210802078247
# 第 17 轮训练，平均 Loss：0.6727
# 第 17 轮测试，平均 Loss：1.2160，准确率：61.97%
#
# -------第18轮训练开始-------
# 训练100个batch耗时：49.090888023376465秒
# 训练次数：13300， Loss：0.6703982949256897
# 训练100个batch耗时：49.406129121780396秒
# 训练次数：13400， Loss：0.539771318435669
# 训练100个batch耗时：49.723758697509766秒
# 训练次数：13500， Loss：0.5294907093048096
# 训练100个batch耗时：50.037559509277344秒
# 训练次数：13600， Loss：0.8881032466888428
# 训练100个batch耗时：50.3498911857605秒
# 训练次数：13700， Loss：0.5862482190132141
# 训练100个batch耗时：50.66562581062317秒
# 训练次数：13800， Loss：0.5942691564559937
# 训练100个batch耗时：50.975393533706665秒
# 训练次数：13900， Loss：0.6290650367736816
# 训练100个batch耗时：51.28845763206482秒
# 训练次数：14000， Loss：0.4488897919654846
# 第 18 轮训练，平均 Loss：0.6429
# 第 18 轮测试，平均 Loss：1.2076，准确率：62.65%
#
# -------第19轮训练开始-------
# 训练100个batch耗时：51.99094343185425秒
# 训练次数：14100， Loss：0.8657413125038147
# 训练100个batch耗时：52.3034405708313秒
# 训练次数：14200， Loss：0.7047728896141052
# 训练100个batch耗时：52.617019176483154秒
# 训练次数：14300， Loss：0.7380445003509521
# 训练100个batch耗时：52.92943525314331秒
# 训练次数：14400， Loss：0.6412332057952881
# 训练100个batch耗时：53.24240040779114秒
# 训练次数：14500， Loss：0.7012350559234619
# 训练100个batch耗时：53.555556535720825秒
# 训练次数：14600， Loss：0.9249123930931091
# 训练100个batch耗时：53.86776041984558秒
# 训练次数：14700， Loss：0.4789176285266876
# 训练100个batch耗时：54.18049955368042秒
# 训练次数：14800， Loss：0.7720483541488647
# 第 19 轮训练，平均 Loss：0.6144
# 第 19 轮测试，平均 Loss：1.1947，准确率：63.77%
# 保存最佳模型！准确率：63.77%
#
# -------第20轮训练开始-------
# 训练100个batch耗时：54.88853216171265秒
# 训练次数：14900， Loss：0.41775310039520264
# 训练100个batch耗时：55.20023250579834秒
# 训练次数：15000， Loss：0.5597718954086304
# 训练100个batch耗时：55.51376509666443秒
# 训练次数：15100， Loss：0.6099470257759094
# 训练100个batch耗时：55.82509994506836秒
# 训练次数：15200， Loss：0.6798564791679382
# 训练100个batch耗时：56.141090393066406秒
# 训练次数：15300， Loss：0.5299119353294373
# 训练100个batch耗时：56.45639991760254秒
# 训练次数：15400， Loss：0.6420396566390991
# 训练100个batch耗时：56.7735481262207秒
# 训练次数：15500， Loss：0.6886242628097534
# 训练100个batch耗时：57.08691906929016秒
# 训练次数：15600， Loss：0.5596294403076172
# 第 20 轮训练，平均 Loss：0.5864
# 第 20 轮测试，平均 Loss：1.2285，准确率：63.59%
# 保存第20轮次的模型
#
# 🎉 训练完成！最佳准确率：63.77%
# 模型已保存到 ../checkpoints/ 目录

# %% [markdown]
# # 4 模型测试

# %% [markdown]
# 第一步：定义测试图片

# %%
img_path = '../images/dog.png'
image = Image.open(img_path)
print(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=462x314 at 0x726F580DAB30>

# %% [markdown]
# 第二步：修改图片格式

# %%
# 将PNG转换为RGB
image = image.convert('RGB')

transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((32, 32)),
    torchvision.transforms.ToTensor()
])

image = transform(image)

print(image.shape)
# Out:
# torch.Size([3, 32, 32])

# %%
image = torch.reshape(input=image, shape=(1, 3, 32, 32))
print(image.shape)
# Out:
# torch.Size([1, 3, 32, 32])

# %% [markdown]
# 第三步：加载模型权重

# %%
model = Model_CIFAR()

model.load_state_dict(torch.load('../checkpoints/CIFRA10/best_model.pth'))

print(model)
# Out:
# Model_CIFAR(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): Conv2d(32, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Flatten(start_dim=1, end_dim=-1)
#   )
#   (classfier): Sequential(
#     (0): Linear(in_features=1024, out_features=64, bias=True)
#     (1): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# 第四步：测试

# %%
model.eval()
with torch.no_grad():
    output = model(image)
print(output)
print(output.argmax(1))
print()
# Out:
# tensor([[ -0.1705,  -6.0084,   6.5984,   4.1745,   0.7554,   8.5085,  -5.7296,
#            9.7404, -13.5578,  -9.0026]])
# tensor([7])
